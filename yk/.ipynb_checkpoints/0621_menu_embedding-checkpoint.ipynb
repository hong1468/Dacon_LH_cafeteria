# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
#from lightgbm import LGBMRegressor

#from gensim.models import Word2Vec
#from gensim.models import KeyedVectors
#from sklearn.manifold import TSNE
#from sklearn.decomposition import PCA

warnings.filterwarnings(action='ignore')

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
submission = pd.read_csv('data/sample_submission.csv')

# %%
# Basic text preprocessing

def split_process(x, q):
    x_ = []
    x = x.split(' ')
    for i in x:
        if '(' in i and ':' in i and ')' in i:
            continue
        if '/' in i:
            x_.extend(i.split('/'))
        else:
            x_.append(i)
    x_ = list(set(x_))
    x_.remove('')
    return x_

# %%
food_combinations = []
for i in ['조식메뉴', '중식메뉴', '석식메뉴']:
    food_combinations += train[i].apply(lambda x: split_process(x, i)).to_list()

# %%
train['조식메뉴2'] = train[i].apply(lambda x: split_process(x, i))

# %%
food_combinations
# Out:
# [['두유',
#   '호두죽',
#   '주스',
#   '포기김치',
#   '된장찌개',
#   '쌀밥',
#   '우유',
#   '쥐어채무침',
#   '찐빵',
#   '계란후라이',
#   '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '단호박샌드',
#   '팥죽',
#   '호박젓국찌개',
#   '계란후라이',
#   '시래기조림',
#   '모닝롤'],
#  ['느타리호박볶음',
#   '두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '표고버섯죽',
#   '모닝롤',
#   '콩나물국',
#   '계란후라이',
#   '베이글'],
#  ['멸치볶음',
#   '두유',
#   '닭죽',
#   '주스',
#   '근대국',
#   '포기김치',
#   '쌀밥',
#   '우유',
#   '토마토샌드',
#   '계란후라이',
#   '모닝롤'],
#  ['와플', '두유', '포기김치', '주스', '방풍나물', '쌀밥', '우유', '재첩국', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '팬케익',
#   '찐빵',
#   '명엽채무침',
#   '견과류죽',
#   '계란후라이',
#   '감자찌개'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '야채샌드',
#   '우유',
#   '숙주나물',
#   '봄동된장국',
#   '고구마죽',
#   '계란후라이',
#   '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '잣죽',
#   '우유',
#   '치즈프레즐',
#   '콩조림',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤'],
#  ['두유', '포기김치', '주스', '단호박죽', '어묵국', '쌀밥', '김구이', '우유', '마늘빵', '계란후라이', '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '무생채',
#   '쌀밥',
#   '흑임자죽',
#   '우유',
#   '북어계란국',
#   '참치샌드',
#   '계란후라이',
#   '모닝롤'],
#  ['두유', '포기김치', '인절미토스트', '주스', '우유', '톳두부무침', '선지해장국', '계란후라이', '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '밤죽',
#   '홍합탕',
#   '오이생채',
#   '계란후라이',
#   '모닝롤'],
#  ['시금치나물', '포기김치', '브로컬리죽', '주스', '쌀밥', '우유', '팬케익', '고추장찌개', '계란후라이', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '참나물땅콩가루무침', '쌀밥', '야채샌드', '우유', '재첩국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '무채국', '쌀밥', '우유', '꿀호떡', '김치죽', '계란후라이', '애호박나물', '모닝롤'],
#  ['크로와상', '포기김치', '주스', '쌀밥', '우유', '봄동된장국', '어묵볶음', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '에그샌드', '밤죽', '꽃게탕', '계란후라이', '시래기조림', '모닝롤'],
#  ['두유',
#   '호두죽',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '콩나물김치국',
#   '우유',
#   '계란후라이',
#   '곰피초장',
#   '프렌치토스트',
#   '모닝롤'],
#  ['단팥빵',
#   '두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '오이무침',
#   '올갱이아욱국',
#   '계란후라이',
#   '참치야채죽',
#   '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '피바지락국',
#   '쌀밥',
#   '우유',
#   '팥죽',
#   '바나나샌드',
#   '가지볶음',
#   '계란후라이',
#   '모닝롤'],
#  ['두유',
#   '포기김치',
#   '사과파이',
#   '주스',
#   '쌀밥',
#   '우유',
#   '야채죽',
#   '볼어묵볶음',
#   '시금치국',
#   '계란후라이',
#   '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '무채국',
#   '쌀밥',
#   '우유',
#   '땅콩죽',
#   '쑥갓무침',
#   '브라우니',
#   '계란후라이',
#   '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '새송이죽',
#   '유채나물',
#   '호박젓국찌개',
#   '고구마샌드',
#   '계란후라이',
#   '모닝롤'],
#  ['두유', '포기김치', '주스', '단호박죽', '어묵국', '쌀밥', '우유', '김자반', '롤케익', '계란후라이', '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '냉이된장국',
#   '명엽채무침',
#   '햄치즈샌드',
#   '녹두죽',
#   '계란후라이',
#   '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '검정콩조림',
#   '쌀밥',
#   '우유',
#   '찐빵',
#   '고구마죽',
#   '재첩국',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '롤케이크', '미역줄기볶음', '황태국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '쇠고기무국', '에그샌드', '해물죽', '브로컬리들깨찜', '계란후라이', '모닝롤'],
#  ['느타리호박볶음',
#   '포기김치',
#   '시래기국',
#   '주스',
#   '쌀밥',
#   '우유',
#   '치즈프레즐',
#   '홍게살죽',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '베이컨샌드', '주스', '브로컬리죽', '쌀밥', '우유', '오징어국', '숙주나물', '계란후라이', '모닝롤'],
#  ['크로와상', '들깨미역국', '포기김치', '주스', '방풍나물', '쌀밥', '우유', '표고버섯죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '무채국', '쌀밥', '김치죽', '우유', '김실파무침', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '브로컬리초장',
#   '우유',
#   '선지해장국',
#   '계란후라이',
#   '참치야채죽',
#   '모닝롤'],
#  ['근대국', '포기김치', '주스', '쌀밥', '우유', '쑥갓두부무침', '새송이버섯죽', '카스텔라', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '순두부국', '쌀밥', '우유', '크랜베리멸치볶음', '밤죽', '토마토샌드', '계란후라이', '모닝롤'],
#  ['와플', '포기김치', '주스', '쌀밥', '우유', '진미채무침', '콩나물국', '견과류죽', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '새우살죽',
#   '두부김치국',
#   '미역레몬초무침',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '야채죽', '오이무침', '쇠고기버섯국', '참치샌드', '계란후라이', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '핫도그', '우유', '참나물무침', '계란후라이', '감자국', '모닝롤'],
#  ['단팥빵', '포기김치', '주스', '늙은호박죽', '마늘쫑무침', '쌀밥', '우유', '바지락쑥국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '녹두죽', '계란후라이', '민물새우찌개', '구이김', '모닝롤'],
#  ['두유', '근대국', '주스', '마늘쫑무침', '포기김치', '쌀밥', '잣죽', '우유', '팬케익', '계란후라이', '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '미역줄기볶음',
#   '우유',
#   '두부젓국찌개',
#   '단호박샌드',
#   '양송이죽',
#   '계란후라이',
#   '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '방풍나물',
#   '쌀밥',
#   '우유',
#   '치즈프레즐',
#   '팥죽',
#   '꽃게탕',
#   '계란후라이',
#   '모닝롤'],
#  ['치킨샌드',
#   '두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '흑임자죽',
#   '우유',
#   '진미채무침',
#   '계란후라이',
#   '열무된장국',
#   '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '대구찌개',
#   '쌀밥',
#   '우유',
#   '콩조림',
#   '고구마죽',
#   '브라우니',
#   '계란후라이',
#   '모닝롤'],
#  ['두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '김자반',
#   '고추장찌개',
#   '견과류죽',
#   '마늘빵',
#   '계란후라이',
#   '모닝롤'],
#  ['얼갈이된장국',
#   '두유',
#   '포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '감자채볶음',
#   '쇠고기죽',
#   '계란후라이',
#   '모닝롤'],
#  ['두유',
#   '브로컬리죽',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '우유',
#   '에그샌드',
#   '콩나물무침',
#   '황태국',
#   '계란후라이',
#   '모닝롤'],
#  ['크로와상',
#   '두유',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '새우살죽',
#   '시금치나물',
#   '재첩국',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '오이무침', '꿀호떡', '계란후라이', '감자국', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '표고버섯죽',
#   '곤약어묵볶음',
#   '토마토샌드',
#   '콩나물국',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '느타리볶음', '쌀밥', '우유', '모닝롤', '김치국', '홍게살죽', '계란후라이', '베이글'],
#  ['포기김치', '주스', '늙은호박죽', '비름나물', '쌀밥', '우유', '선지해장국', '고구마샌드', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '아욱국', '우유', '숙주나물', '고구마죽', '카스텔라', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '김구이', '쌀밥', '우유', '계란후라이', '땅콩죽', '차돌박이찌개', '프렌치토스트', '모닝롤'],
#  ['열무나물', '포기김치', '베이컨샌드', '주스', '쌀밥', '우유', '연두부탕', '녹두죽', '계란후라이', '모닝롤'],
#  ['와플', '포기김치', '닭죽', '주스', '쌀밥', '우유', '매운어묵국', '감자채볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '표고버섯죽', '마늘쫑볶음', '롤케익', '계란후라이', '우거지해장국', '모닝롤'],
#  ['야채햄샌드', '포기김치', '주스', '쌀밥', '우유', '진미채무침', '우렁살된장국', '김치죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '야채죽', '호박젓국찌개', '김자반', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '오이도라지무침', '우유', '팥죽', '옥수수샌드', '재첩국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '콩나물김치국', '우유', '밤죽', '찐빵', '브로컬리들깨찜', '계란후라이', '모닝롤'],
#  ['들깨미역국', '호두죽', '주스', '포기김치', '쌀밥', '우유', '진미채무침', '팬케익', '계란후라이', '모닝롤'],
#  ['근대국', '브로컬리죽', '주스', '포기김치', '쌀밥', '우유', '에그샌드', '감자채볶음', '계란후라이', '모닝롤'],
#  ['크로와상', '포기김치', '주스', '쌀밥', '우유', '호박나물', '느타리버섯국', '홍게살죽', '계란후라이', '모닝롤'],
#  ['취나물', '포기김치', '주스', '쌀밥', '우유', '야채죽', '북어계란국', '참치샌드', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '아욱국', '치즈프레즐', '노각무침', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '우유', '계란후라이', '연두부탕', '김자반', '프렌치토스트', '모닝롤'],
#  ['포기김치', '주스', '느타리볶음', '쌀밥', '우유', '새우살죽', '콩나물국', '스크램블에그', '햄치즈샌드', '모닝롤'],
#  ['단팥빵', '포기김치', '주스', '쌀밥', '우유', '어묵볶음', '쇠고기죽', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['포기김치', '주스', '대구찌개', '씨크립샌드', '쌀밥', '우유', '양송이죽', '명엽채무침', '스크램블에그', '모닝롤'],
#  ['근대국', '포기김치', '주스', '단호박죽', '쌀밥', '우유', '고구마파이', '머위대나물', '계란후라이', '모닝롤'],
#  ['얼갈이된장국', '포기김치', '주스', '쌀밥', '우유', '땅콩죽', '미역레몬초무침', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '인절미토스트', '김구이', '쌀밥', '우유', '콩나물국', '스크램블에그', '녹두죽', '모닝롤'],
#  ['열무김치', '주스', '검정콩조림', '쌀밥', '야채샌드', '우유', '올갱이아욱국', '김치죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '마늘쫑무침', '소라살죽', '쌀밥', '어묵국', '우유', '모닝롤', '스크램블에그', '베이글'],
#  ['포기김치', '주스', '피바지락국', '쌀밥', '브로컬리초장', '식빵피자', '우유', '밤죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '미역국', '멸치캐슈넛볶음', '카스텔라', '계란후라이', '모닝롤'],
#  ['치킨샌드', '포기김치', '주스', '쌀밥', '우유', '새우살죽', '쇠고기무국', '가지나물', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '팥죽', '홍초콩나물국', '김자반', '브라우니', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '야채죽', '에그샌드', '스크램블에그', '황태국', '애호박나물', '모닝롤'],
#  ['크로와상', '열무김치', '주스', '무채국', '쌀밥', '우유', '사각어묵무침', '홍게살죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '치즈프레즐', '두부김치국', '명엽채무침', '견과류죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '아욱국', '우유', '바나나샌드', '고구마죽', '오이생채', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '늙은호박죽', '쌀밥', '핫도그', '우유', '느타리버섯국', '숙주나물', '스크램블에그', '모닝롤'],
#  ['취나물', '포기김치', '주스', '쌀밥', '우유', '토마토샌드', '꽃게탕', '계란후라이', '참치야채죽', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '멸치고추장무침',
#   '쌀밥',
#   '잣죽',
#   '우유',
#   '계란후라이',
#   '쇠고기무국',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '새송이버섯볶음', '쌀밥', '우유', '동태찌개', '옥수수샌드', '녹두죽', '계란후라이', '모닝롤'],
#  ['와플', '포기김치', '주스', '쌀밥', '우유', '감자채볶음', '시금치국', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '베이컨샌드',
#   '주스',
#   '쌀밥',
#   '우유',
#   '표고버섯죽',
#   '고구마순나물',
#   '콩나물국',
#   '계란후라이',
#   '모닝롤'],
#  ['느타리호박볶음', '포기김치', '닭죽', '주스', '쌀밥', '우유', '팬케익', '계란후라이', '우거지해장국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '야채죽', '진미채무침', '마늘빵', '계란후라이', '근대된장국', '모닝롤'],
#  ['포기김치', '김치콩나물국', '주스', '쌀밥', '흑임자죽', '우유', '김자반', '고구마샌드', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '오징어국', '팥죽', '스크램블에그', '노각무침', '롤케익', '모닝롤'],
#  ['치킨샌드', '열무김치', '주스', '검정콩조림', '쌀밥', '우유', '홍게살죽', '북어계란국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '비름나물', '된장찌개', '쌀밥', '우유', '밤죽', '모닝롤', '계란후라이', '베이글'],
#  ['포기김치',
#   '주스',
#   '북어콩나물국',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '땅콩죽',
#   '쥐어채무침',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '느타리볶음', '햄야채샌드', '쌀밥', '우유', '새우살미역국', '녹두죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '우유', '동태찌개', '스크램블에그', '애플파이', '애호박나물', '모닝롤'],
#  ['단팥빵', '포기김치', '주스', '단호박죽', '쌀밥', '우유', '가지나물', '소고기무국', '계란후라이', '모닝롤'],
#  ['포기김치', '브로컬리죽', '주스', '쌀밥', '볼어묵조림', '우유', '시금치국', '참치샌드', '계란후라이', '모닝롤'],
#  ['포기김치', '호두죽', '주스', '두부조림', '무채국', '쌀밥', '우유', '카스텔라', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '표고버섯죽', '바나나샌드', '시금치나물', '꽃게탕', '계란후라이', '모닝롤'],
#  ['크로와상', '포기김치', '닭죽', '주스', '쌀밥', '우유', '느타리버섯국', '명엽채무침', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '김치콩나물국',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '멸치호두볶음',
#   '스크램블에그',
#   '쇠고기죽',
#   '모닝롤'],
#  ['근대국', '포기김치', '주스', '쌀밥', '우유', '치즈프레즐', '머위대나물', '김치죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '마늘쫑볶음', '모닝롤', '계란후라이', '감자국', '베이글'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '쇠고기무국',
#   '에그샌드',
#   '홍게살죽',
#   '계란후라이',
#   '숙주미나리나물',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '대구찌개',
#   '쌀밥',
#   '우유',
#   '고구마순나물',
#   '스크램블에그',
#   '브라우니',
#   '참치야채죽',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '진미채무침', '새송이죽', '새알미역국', '햄치즈샌드', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '찐빵', '팥죽', '두부김치국', '김자반', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '계란후라이', '땅콩죽', '명엽채무침', '시금치국', '프렌치토스트', '모닝롤'],
#  ['포기김치', '주스', '어묵국', '쌀밥', '우유', '토마토샌드', '스크램블에그', '콩자반', '녹두죽', '모닝롤'],
#  ['포기김치', '주스', '무채국', '쌀밥', '우유', '오이무침', '고구마파이', '양송이죽', '계란후라이', '모닝롤'],
#  ['버섯볶음', '포기김치', '주스', '쌀밥', '우유', '해물죽', '옥수수샌드', '계란후라이', '근대된장국', '모닝롤'],
#  ['멸치볶음', '포기김치', '닭죽', '주스', '쌀밥', '우유', '계란후라이', '북어계란국', '바나나팬케이크', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '김실파무침', '우유', '마늘빵', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '식빵피자', '우유', '바지락콩나물국', '김치죽', '시래기나물', '계란후라이', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '고추장찌개', '브로컬리들깨찜', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '새우살죽', '에그샌드', '숙주나물', '계란후라이', '감자국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '스크램블', '우유', '북어국', '카스텔라', '쇠고기죽', '애호박나물', '모닝롤'],
#  ['근대국',
#   '보리누룽지탕',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '프렌치토스트',
#   '사각어묵볶음',
#   '모닝롤'],
#  ['포기김치', '주스', '씨크립샌드', '단호박죽', '쌀밥', '우유', '오징어국', '스크램블에그', '새송이볶음', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '치즈프레즐', '김자반', '차돌박이찌개', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '야채죽',
#   '크랜베리멸치볶음',
#   '느타리버섯국',
#   '구운계란',
#   '참치샌드',
#   '모닝롤'],
#  ['크로와상', '포기김치', '주스', '쌀밥', '우유', '동태찌개', '아삭고추무침', '홍게살죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '김치두부국', '포기김치', '주스', '쌀밥', '우유', '명엽채무침', '롤케익', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '호박볶음', '쌀밥', '우유', '야채죽', '올갱이아욱국', '스크램블에그', '고구마샌드', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '새우살미역국', '고구마순나물', '모닝롤', '계란후라이', '베이글'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '참나물땅콩무침', '쇠고기샤브국', '구운계란', '녹두죽', '모닝롤'],
#  ['와플', '포기김치', '주스', '쌀밥', '우유', '해물죽', '가지볶음', '계란후라이', '감자국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '우유', '진미채무침', '북어국', '꿀호떡', '스크램블에그', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '어묵국', '쌀밥', '우유', '토마토샌드', '콩나물무침', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '미역줄기볶음', '구운계란', '브라우니', '우거지해장국', '모닝롤'],
#  ['포기김치', '주스', '도라지나물', '쌀밥', '우유', '오징어국', '옥수수샌드', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['와플', '포기김치', '주스', '새송이버섯볶음', '쌀밥', '잣죽', '우유', '스크램블에그', '우거지해장국', '모닝롤'],
#  ['호박죽', '조랭이떡미역국', '포기김치', '주스', '쌀밥', '우유', '꽈리고추찜', '참치샌드', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '북어국', '찐빵', '애호박볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '김잔파무침', '인절미샌드', '고구마죽', '구운계란', '시금치국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '도라지나물', '쌀밥', '우유', '민물새우찌깨', '카스텔라', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '계란후라이', '느타리버섯국', '김자반', '프렌치토스트', '모닝롤'],
#  ['근대국', '포기김치', '주스', '쌀밥', '우유', '야채죽', '명엽채무침', '바나나샌드', '구운계란', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '사과파이',
#   '대구찌개',
#   '쌀밥',
#   '우유',
#   '크림누룽지탕',
#   '곤약어묵볶음',
#   '스크램블에그',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '고구마순나물', '햄에그치즈토스트', '콩나물국', '구운계란', '김치죽'],
#  ['크로와상', '포기김치', '주스', '맑은만두육개장', '쌀밥', '우유', '가지나물', '팥죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '감자조림', '호박젓국찌개', '구운계란', '바나나팬케익', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '에그샌드', '콩나물된장국', '해물죽', '스크램블에그', '구이김', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '쇠고기무국', '진미채무침', '모닝롤', '계란후라이', '베이글'],
#  ['김치두부국', '취나물', '주스', '늙은호박죽', '포기김치', '쌀밥', '우유', '구운계란', '햄치즈샌드', '모닝롤'],
#  ['단팥빵', '포기김치', '주스', '쌀밥', '미역줄기볶음', '우유', '땅콩죽', '아욱된장국', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '고구마파이', '꽃게탕', '김자반', '구운계란', '모닝롤'],
#  ['멸치볶음', '포기김치', '주스', '쌀밥', '우유', '새송이죽', '토마토샌드', '스크램블에그', '감자국', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '북어해장국', '김구이', '쌀밥', '우유', '구운계란', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '우유', '쇠고기미역국', '명엽채무침', '스크램블에그', '고구마샌드', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '사과파이',
#   '쌀밥',
#   '우유',
#   '김가루실파무침',
#   '버섯들깨탕',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '브로컬리들깨무침',
#   '된장찌개',
#   '쌀밥',
#   '우유',
#   '구운계란',
#   '옥수수샌드',
#   '쇠고기죽',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '숙주나물', '크림누룽지탕', '김치국', '카스텔라', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '미역줄기볶음', '우유', '계란후라이', '꽃게탕', '프렌치토스트', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '도라지나물',
#   '씨크립샌드',
#   '쌀밥',
#   '흑임자죽',
#   '우유',
#   '스크램블에그',
#   '민물새우찌개',
#   '모닝롤'],
#  ['포기김치', '주스', '맑은만두육개장', '무생채', '쌀밥', '우유', '치즈프레즐', '수삼닭죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '에그샌드', '치커리무침', '구운계란', '감자국', '모닝롤'],
#  ['크로와상',
#   '포기김치',
#   '주스',
#   '단호박죽',
#   '쌀밥',
#   '우유',
#   '크랜베리멸치볶음',
#   '콩나물국',
#   '계란후라이',
#   '모닝롤'],
#  ['북어채국', '포기김치', '주스', '견과류죽', '쌀밥', '우유', '후르츠팬케익', '김자반', '구운계란', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '어묵국', '쌀밥', '우유', '스크램블에그', '참치샌드', '감자채볶음', '모닝롤'],
#  ['구구마순나물', '포기김치', '주스', '쌀밥', '우유', '해물죽', '고추장찌개', '구운계란', '브라우니', '모닝롤'],
#  ['포기김치', '베이컨샌드', '주스', '쌀밥', '우유', '연두부탕', '팥죽', '계란후라이', '시래기조림', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '검정콩조림',
#   '쌀밥',
#   '우유',
#   '홍게살죽',
#   '호박젓국찌개',
#   '구운계란',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '양송이죽', '오징어국', '바나나샌드', '미역나물', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '얼큰소고기국', '스크램블에그', '롤케익', '모닝롤'],
#  ['김치두부국', '브로컬리죽', '주스', '포기김치', '쌀밥', '식빵피자', '우유', '꽈리고추찜', '구운계란', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '아욱국', '우유', '진미채무침', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '명엽채무침', '구운계란', '마늘빵', '감자국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '매운버섯국', '시금치나물', '녹두죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '북어해장국', '쌀밥', '우유', '모닝롤', '스크램블에그', '감자채볶음', '베이글'],
#  ['포기김치', '주스', '늙은호박죽', '씨크립샌드', '쌀밥', '우유', '연근조림', '고추장찌개', '구운계란', '모닝롤'],
#  ['누룽지탕', '프레즐', '포기김치', '주스', '쌀밥', '우유', '쇠고기무국', '콩나물무침', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '삶은계란', '어묵국', '쌀밥', '우유', '고구마순나물', '찐빵', '모닝롤'],
#  ['근대국', '포기김치', '주스', '쌀밥', '우유', '오이무침', '견과류죽', '햄치즈샌드', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '연두부찌개',
#   '포기김치',
#   '주스',
#   '삶은계란',
#   '쌀밥',
#   '마늘쫑맛살볶음',
#   '우유',
#   '단호박샌드',
#   '모닝롤'],
#  ['호박죽',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '고구마파이',
#   '스크램블에그',
#   '모시조개시금치국',
#   '가지나물',
#   '모닝롤'],
#  ['쥐포무침', '포기김치', '주스', '인절미토스트', '쌀밥', '우유', '야채죽', '콩나물국', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '들깨미역국',
#   '포기김치',
#   '주스',
#   '호박볶음',
#   '쌀밥',
#   '우유',
#   '후르츠팬케익',
#   '스크램블에그',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '에그샌드', '콩조림', '아욱된장국', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['크로와상', '누룽지탕', '포기김치', '주스', '대구찌개', '쌀밥', '우유', '스크램블에그', '김자반', '모닝롤'],
#  ['포기김치', '시래기국', '주스', '삶은계란', '두부조림', '쌀밥', '우유', '양송이죽', '토마토샌드', '모닝롤'],
#  ['김치두부국', '닭죽', '주스', '포기김치', '브로컬리들깨무침', '쌀밥', '우유', '브라우니', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '북어해장국', '쌀밥', '우유', '김잔파무침', '스크램블에그', '마늘빵', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '청포묵무침',
#   '크림누룽지탕',
#   '고추장찌개',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '맑은만두육개장',
#   '쌀밥',
#   '우유',
#   '스크램블에그',
#   '시금치나물',
#   '애플파이',
#   '모닝롤'],
#  ['포기김치', '주스', '삶은계란', '마늘쫑무침', '쌀밥', '식빵피자', '우유', '야채죽', '어묵탕', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '가지두반장볶음', '건새우무국', '롤케익', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '진미채무침', '스크램블에그', '바나나팬케익', '감자국', '모닝롤'],
#  ['포기김치', '주스', '피바지락국', '쌀밥', '우유', '에그샌드', '밤죽', '계란후라이', '시래기조림', '모닝롤'],
#  ['누룽지탕', '포기김치', '우엉조림', '주스', '쌀밥', '우유', '찐빵', '얼큰소고기국', '스크램블에그', '모닝롤'],
#  ['포기김치', '주스', '삶은계란', '쌀밥', '야채샌드', '우유', '미역줄기볶음', '홍게살죽', '호박젓국찌개', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '고구마파이', '팥죽', '콩나물무침', '계란후라이', '근대된장국', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '콩나물국',
#   '스크램블에그',
#   '쑥갓두부무침',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '무채국', '쌀밥', '우유', '해물죽', '명엽채무침', '참치샌드', '계란후라이', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '꽈리고추찜', '스크램블에그', '재첩국', '모닝롤'],
#  ['포기김치', '주스', '삶은계란', '단호박죽', '쌀밥', '아욱국', '우유', '바나나샌드', '숙주미나리나물', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '치즈프레즐', '꽃게탕', '느타리버섯볶음', '녹두죽', '계란후라이', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '스크램블에그', '호박젓국찌개', '치커리무침', '모닝롤'],
#  ['포기김치', '주스', '어묵국', '쌀밥', '방풍나물', '우유', '새우살죽', '옥수수샌드', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '스크램블에그', '김자반', '고추장찌개', '카스텔라', '모닝롤'],
#  ['쥐포무침', '포기김치', '주스', '삶은계란', '쌀밥', '우유', '땅콩죽', '토마토샌드', '배추된장국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '팥죽', '모닝롤', '황태국', '계란후라이', '새송이볶음', '베이글'],
#  ['누룽지탕', '포기김치', '주스', '무채국', '쌀밥', '우유', '오이무침', '스크램블에그', '마늘빵', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '북어계란국', '롤케익', '계란후라이', '애호박나물', '모닝롤'],
#  ['누룽지탕', '냉이국', '포기김치', '주스', '두부조림', '쌀밥', '우유', '스크램블에그', '고구마샌드', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '삶은계란', '쌀밥', '야채샌드', '우유', '호박젓국찌개', '시래기조림', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '진미채무침', '얼갈이국', '모닝롤', '해물죽', '계란후라이', '베이글'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '토란국', '스크램블에그', '꽃맛살볶음', '프렌치토스트', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '검정콩조림',
#   '쌀밥',
#   '우유',
#   '크림누룽지탕',
#   '바나나샌드',
#   '선지해장국',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕',
#   '녹차카스테라',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '미역줄기볶음',
#   '우유',
#   '연두부탕',
#   '스크램블에그',
#   '모닝롤'],
#  ['포기김치', '주스', '삶은계란', '씨크립샌드', '어묵국', '쌀밥', '우유', '콩나물무침', '참치야채죽', '모닝롤'],
#  ['포기김치', '주스', '김구이', '쌀밥', '잣죽', '우유', '치즈프레즐', '재첩국', '계란후라이', '모닝롤'],
#  ['누룽지탕', '김치두부국', '멸치볶음', '주스', '포기김치', '쌀밥', '우유', '팬케익', '스크램블에그', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '단호박샌드',
#   '해물죽',
#   '미니새송이볶음',
#   '계란후라이',
#   '열무된장국',
#   '모닝롤'],
#  ['크로와상', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '쇠고기매운국', '스크램블에그', '김자반', '모닝롤'],
#  ['근대국', '포기김치', '주스', '삶은계란', '쌀밥', '우유', '에그샌드', '양송이죽', '명엽채무침', '모닝롤'],
#  ['호박죽', '시금치나물', '포기김치', '주스', '쌀밥', '우유', '고추장찌개', '브라우니', '계란후라이', '모닝롤'],
#  ['누룽지탕', '쥐포무침', '포기김치', '주스', '쌀밥', '아욱국', '우유', '찐빵', '스크램블에그', '모닝롤'],
#  ['포기김치',
#   '베이컨샌드',
#   '주스',
#   '쌀밥',
#   '우유',
#   '홍게살죽',
#   '브로컬리들깨찜',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤'],
#  ['누룽지탕',
#   '느타리호박볶음',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '고구마파이',
#   '스크램블에그',
#   '북어계란국',
#   '모닝롤'],
#  ['포기김치', '주스', '삶은계란', '쌀밥', '우유', '새송이죽', '유채나물', '햄치즈샌드', '감자국', '모닝롤'],
#  ['와플', '취나물', '포기김치', '주스', '쌀밥', '우유', '매운어묵국', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '냉이된장국', '콩자반', '스크램블에그', '마늘빵', '모닝롤'],
#  ['포기김치', '주스', '인절미토스트', '쌀밥', '우유', '새우살죽', '톳무침', '차돌박이찌개', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '사과파이', '쌀밥', '우유', '진미채무침', '토란탕', '스크램블에그', '모닝롤'],
#  ['포기김치', '주스', '삶은계란', '쌀밥', '우유', '오이무침', '밤죽', '연두부탕', '토마토샌드', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '겨울초나물', '모닝롤', '김치국', '쇠고기죽', '계란후라이', '베이글'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '두부조림',
#   '쌀밥',
#   '우유',
#   '느타리버섯국',
#   '바나나팬케익',
#   '계란후라이',
#   '모닝롤'],
#  ['근대국', '포기김치', '주스', '쌀밥', '우유', '숙주나물', '해물죽', '피자토스트', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '맑은만두육개장',
#   '쌀밥',
#   '미역줄기볶음',
#   '우유',
#   '꿀호떡',
#   '스크램블에그',
#   '모닝롤'],
#  ['포기김치', '주스', '마늘쫑무침', '씨크립샌드', '쌀밥', '흑임자죽', '우유', '재첩국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '북어국', '찐빵', '크림누룽지탕', '무채나물', '계란후라이', '모닝롤'],
#  ['누룽지탕', '취나물', '포기김치', '주스', '쌀밥', '우유', '계란후라이', '고추장찌개', '프렌치토스트', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '팥죽', '스크램블에그', '어묵볶음', '열무된장국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '명엽채무침', '꽃게탕', '롤케익', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '땅콩죽',
#   '브로컬리무침',
#   '스크램블에그',
#   '참치샌드',
#   '민물새우찌개',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '소라살죽',
#   '쌀밥',
#   '콩나물김치국',
#   '우유',
#   '치즈프레즐',
#   '계란후라이',
#   '새송이볶음',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '가지나물', '북어계란국', '시금치핫케익', '계란후라이', '모닝롤'],
#  ['크로와상', '근대국', '포기김치', '주스', '느타리볶음', '단호박죽', '쌀밥', '우유', '스크램블에그', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '두부젓국찌개', '토마토샌드', '김자반', '계란후라이', '모닝롤'],
#  ['와플', '포기김치', '주스', '쌀밥', '크래미숙주무침', '우유', '야채죽', '오징어국', '스크램블에그', '모닝롤'],
#  ['포기김치', '주스', '김구이', '쌀밥', '우유', '땅콩죽', '치즈프레즐', '스크램블에그', '꽃게탕', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '검정콩조림', '쌀밥', '우유', '옥수수샌드', '황태국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '연근조림', '고구마파이', '시금치죽', '스크램블에그', '선지해장국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '새송이죽', '바나나샌드', '홍합탕', '계란후라이', '겨울초겉절이', '모닝롤'],
#  ['누룽지탕',
#   '느타리호박볶음',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '콩나물김치국',
#   '우유',
#   '스크램블에그',
#   '마늘빵',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '단호박샌드', '가지나물', '양송이죽', '재첩국', '계란후라이', '모닝롤'],
#  ['호박죽', '포기김치', '주스', '사과파이', '쌀밥', '우유', '어묵볶음', '스크램블에그', '아욱된장국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '삶은계란', '쌀밥', '우유', '오이무침', '참치샌드', '감자국', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '우유', '맑은연두부탕', '참나물생채', '꿀호떡', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '진미채무침',
#   '봄동된장국',
#   '스크램블에그',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '표고버섯죽',
#   '브로컬리들깨찜',
#   '햄치즈샌드',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '북어국', '아삭고추무침', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '김치콩나물국',
#   '주스',
#   '쌀밥',
#   '우유',
#   '에그샌드',
#   '스크램블에그',
#   '고구마죽',
#   '새송이볶음',
#   '모닝롤'],
#  ['근대국', '포기김치', '주스', '무생채', '쌀밥', '우유', '모닝롤', '홍게살죽', '계란후라이', '베이글'],
#  ['누룽지탕',
#   '포기김치',
#   '달래된장찌개',
#   '주스',
#   '쌀밥',
#   '우유',
#   '크랜베리멸치볶음',
#   '찐빵',
#   '스크램블에그',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '야채샌드',
#   '우유',
#   '해물죽',
#   '스크램블에그',
#   '김가루실파무침',
#   '고추장찌개',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '명엽채무침', '꽃게탕', '브라우니', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '씨크립샌드', '쌀밥', '우유', '스크램블에그', '호박젓국찌개', '녹두죽', '가지나물', '모닝롤'],
#  ['포기김치', '주스', '두부조림', '쌀밥', '우유', '아욱된장국', '롤케익', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '건새우무채국', '주스', '김구이', '쌀밥', '토스트', '우유', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '시금치된장국', '우유', '팥죽', '콩자반', '스크램블에그', '참치샌드', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '우유', '매운감자국', '옥수수샌드', '계란후라이', '시래기조림', '모닝롤'],
#  ['포기김치', '주스', '쇠고기우거지국', '참나물', '쌀밥', '핫도그', '우유', '표고버섯죽', '스크램블에그', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '시래기된장국', '쌀밥', '우유', '팬케익', '쑥갓두부무침', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '북어해장국', '단호박죽', '쌀밥', '우유', '스크램블에그', '햄치즈샌드', '가지나물', '모닝롤'],
#  ['포기김치', '주스', '맑은만두육개장', '쌀밥', '우유', '땅콩죽', '아삭고추무침', '마늘빵', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '피자빵', '유채나물', '재첩국', '계란후라이', '모닝롤'],
#  ['크로와상', '포기김치', '주스', '대구찌개', '쌀밥', '미역줄기볶음', '우유', '야채죽', '스크램블에그', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '계란후라이', '어묵볶음', '프렌치토스트', '감자국', '모닝롤'],
#  ['포기김치', '주스', '느타리볶음', '씨크립샌드', '된장찌개', '쌀밥', '우유', '스크램블에그', '견과류죽', '모닝롤'],
#  ['단팥빵', '쥐포무침', '포기김치', '주스', '쌀밥', '우유', '새우살죽', '두부젓국찌개', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '베이컨샌드', '주스', '쌀밥', '우유', '브로컬리들깨찜', '계란후라이', '쑥국', '모닝롤'],
#  ['김치두부국', '포기김치', '주스', '쌀밥', '흑임자죽', '우유', '치즈프레즐', '스크램블에그', '김자반', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '어묵국', '쌀밥', '미역줄기볶음', '우유', '시금치핫케익', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '바나나샌드', '스크램블에그', '홍게살죽', '들깨감자국', '오이생채', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '김실파무침', '우유', '찐빵', '콩나물국', '김치죽', '계란후라이', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '명엽채볶음', '쌀밥', '우유', '꽃게탕', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '사과파이',
#   '시래기조림',
#   '쌀밥',
#   '우유',
#   '스크램블에그',
#   '선지해장국',
#   '참치야채죽',
#   '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '진미채무침',
#   '건새우아욱국',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '브로컬리죽', '주스', '두부조림', '쌀밥', '우유', '스크램블에그', '배추맑은국', '참치샌드', '모닝롤'],
#  ['느타리호박볶음',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '시래기들깨탕',
#   '메론롤케익',
#   '양송이죽',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '인절미토스트',
#   '쌀밥',
#   '우유',
#   '대추채멸치볶음',
#   '닭곰탕',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '고구마파이', '두부김치국', '스크램블에그', '미역나물', '쇠고기죽', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '사과파이', '무생채', '쌀밥', '우유', '계란후라이', '감자국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '팥죽', '콩나물국', '스크램블에그', '꽃맛살볶음', '햄치즈샌드', '모닝롤'],
#  ['크로와상',
#   '포기김치',
#   '주스',
#   '검정콩조림',
#   '쌀밥',
#   '우유',
#   '크림누룽지탕',
#   '차돌박이찌개',
#   '계란후라이',
#   '모닝롤'],
#  ['두부들깨탕', '주스', '단배추나물', '쌀밥', '우유', '단호박샌드', '깍두기', '홍게살죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '김치황태국', '치즈프레즐', '스크램블에그', '견과류죽', '가지나물', '모닝롤'],
#  ['누룽지탕', '쥐포무침', '포기김치', '주스', '쌀밥', '우유', '팬케익', '콩나물국', '계란후라이', '모닝롤'],
#  ['취나물', '포기김치', '주스', '쌀밥', '우유', '표고버섯죽', '에그샌드', '스크램블에그', '민물새우찌개', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '쇠고기해장국', '유채나물', '계란후라이', '모닝롤'],
#  ['치킨샌드', '포기김치', '주스', '느타리볶음', '쌀밥', '우유', '두부젓국찌개', '밤죽', '계란후라이', '모닝롤'],
#  ['근대국',
#   '포기김치',
#   '주스',
#   '늙은호박죽',
#   '쌀밥',
#   '우유',
#   '마늘쫑건새우볶음',
#   '모닝롤',
#   '스크램블에그',
#   '베이글'],
#  ['누룽지탕', '포기김치', '주스', '어묵국', '쌀밥', '우유', '땅콩조림', '브라우니', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '씨크립샌드', '쌀밥', '우유', '멸치호두볶음', '스크램블에그', '김치죽', '감자국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '오징어국', '찐빵', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '매운버섯국', '쑥갓두부무침', '녹두죽', '계란후라이', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '피바지락국', '쌀밥', '우유', '명엽채무침', '스크램블에그', '롤케익', '모닝롤'],
#  ['누룽지탕', '근대감자국', '포기김치', '주스', '쌀밥', '우유', '계란후라이', '김자반', '프렌치토스트', '모닝롤'],
#  ['포기김치', '주스', '우엉어묵볶음', '쌀밥', '우유', '팥죽', '콩나물국', '스크램블에그', '참치샌드', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '검정콩조림', '된장찌개', '쌀밥', '우유', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '북어해장국', '쌀밥', '우유', '야채죽', '피자빵', '애호박볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '사과파이', '쌀밥', '흑임자죽', '우유', '오이무침', '스크램블에그', '조랭이떡국', '모닝롤'],
#  ['포기김치', '주스', '김구이', '쌀밥', '야채샌드', '우유', '시금치죽', '황태국', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '시래기된장국',
#   '쌀밥',
#   '우유',
#   '진미채무침',
#   '단호박샌드',
#   '홍게살죽',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '멸치크랜베리볶음',
#   '우유',
#   '모닝롤',
#   '계란후라이',
#   '열무된장국',
#   '베이글'],
#  ['포기김치', '주스', '어묵국', '쌀밥', '김구이', '우유', '치즈프레즐', '김치죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '청경채무침', '스크램블에그', '고구마샌드', '감자국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '해물죽', '스크램블에그', '호박젓국찌개', '카스텔라', '가지나물', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '쑥갓두부무침',
#   '프렌치토스트',
#   '민물새우찌개',
#   '모닝롤'],
#  ['북어채국', '포기김치', '주스', '쌀밥', '우유', '야채죽', '에그샌드', '브로컬리들깨찜', '계란후라이', '모닝롤'],
#  ['단팥빵', '누룽지탕', '대구매운탕', '주스', '포기김치', '검정콩조림', '쌀밥', '우유', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '인절미토스트',
#   '참치죽',
#   '쌀밥',
#   '우유',
#   '명엽채무침',
#   '스크램블에그',
#   '우거지해장국',
#   '모닝롤'],
#  ['크로와상', '김치두부국', '포기김치', '주스', '단호박죽', '쌀밥', '우유', '시금치나물', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '어묵국', '쌀밥', '우유', '숙주나물', '크림누룽지탕', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '땅콩죽', '오징어국', '김가루실파무침', '계란후라이', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '애호박볶음', '닭곰탕', '계란후라이', '모닝롤'],
#  ['열무나물', '포기김치', '브로컬리죽', '주스', '쌀밥', '우유', '스크램블에그', '옥수수샌드', '감자국', '모닝롤'],
#  ['포기김치', '주스', '맑은만두육개장', '쌀밥', '우유', '고구마파이', '팥죽', '꽈리고추찜', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '토스트', '우유', '미역국', '대추채멸치볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '비름나물', '쌀밥', '우유', '소고기무국', '토마토샌드', '스크램블에그', '수삼닭죽', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '두부젓국찌개', '모닝롤', '자반김', '계란후라이', '베이글'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '밤죽',
#   '동태찌개',
#   '스크램블에그',
#   '브로컬리들깨소스',
#   '고구마샌드',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '메론롤케익',
#   '건새우아욱국',
#   '홍게살죽',
#   '감자채볶음',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕',
#   '쥐포무침',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '쇠고기버섯국',
#   '시금치핫케익',
#   '계란후라이',
#   '모닝롤'],
#  ['김치두부국', '호두죽', '주스', '포기김치', '쌀밥', '우유', '호박나물', '치즈프레즐', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '어묵국', '쌀밥', '우유', '땅콩조림', '스크램블에그', '참치샌드', '모닝롤'],
#  ['포기김치', '주스', '대구찌개', '쌀밥', '우유', '찐빵', '고구마죽', '계란후라이', '시래기조림', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '느타리볶음', '쌀밥', '우유', '오징어국', '브라우니', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '표고버섯죽',
#   '쑥갓두부무침',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '쇠고기무국',
#   '마늘쫑건새우볶음',
#   '꿀호떡',
#   '계란후라이',
#   '모닝롤'],
#  ['치킨샌드', '포기김치', '주스', '쌀밥', '우유', '진미채무침', '스크램블에그', '시금치국', '김치죽', '모닝롤'],
#  ['포기김치', '주스', '사과파이', '쌀밥', '미역줄기볶음', '우유', '북어국', '녹두죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '꽃게탕', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '비름나물', '무채국', '쌀밥', '우유', '양송이죽', '옥수수샌드', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '새송이버섯볶음',
#   '쌀밥',
#   '우유',
#   '고구마파이',
#   '동태찌개',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '검정콩조림', '쌀밥', '우유', '단호박샌드', '팥죽', '스크램블에그', '열무된장국', '모닝롤'],
#  ['크로와상', '포기김치', '주스', '쌀밥', '잣죽', '우유', '꽈리고추찜', '조랭이떡국', '계란후라이', '모닝롤'],
#  ['누룽지탕', '김치두부국', '포기김치', '주스', '쌀밥', '우유', '팬케익', '느타리버섯볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '해물죽', '호박잎찌개', '김자반', '햄치즈샌드', '계란후라이', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '쇠고기매운국', '고구마순나물', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '베이컨샌드',
#   '주스',
#   '참치죽',
#   '쌀밥',
#   '우유',
#   '스크램블에그',
#   '고추장찌개',
#   '브로컬리두부무침',
#   '모닝롤'],
#  ['크로와상', '포기김치', '시래기국', '주스', '쌀밥', '우유', '오이무침', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '된장찌개', '쌀밥', '우유', '계란후라이', '가지나물', '프렌치토스트', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '두부젓국찌개', '에그샌드', '밤죽', '명엽채무침', '계란후라이', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '호박볶음', '시금치프리타타', '쌀밥', '우유', '오징어국', '모닝롤'],
#  ['포기김치', '주스', '지리멸치볶음', '쌀밥', '우유', '쇠고기무국', '바나나샌드', '녹두죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '단호박죽', '쌀밥', '우유', '메론롤케익', '땅콩조림', '꽃게탕', '계란후라이', '모닝롤'],
#  ['누룽지탕', '쥐포무침', '포기김치', '주스', '쌀밥', '무청된장국', '우유', '찐빵', '계란후라이', '모닝롤'],
#  ['열무나물', '포기김치', '주스', '쌀밥', '식빵피자', '우유', '야채죽', '황태국', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '오이도라지무침', '우유', '브라우니', '계란후라이', '바지락국', '모닝롤'],
#  ['포기김치', '주스', '느타리볶음', '쌀밥', '우유', '연두부탕', '팥죽', '스크램블에그', '고구마샌드', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '새우살죽', '치즈프레즐', '깻순나물', '계란후라이', '우거지해장국', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '김치순두부찌개',
#   '쌀밥',
#   '우유',
#   '호떡',
#   '브로컬리된장무침',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '우유', '콩나물국', '김자반', '햄치즈샌드', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '쇠고기미역국', '모닝롤', '계란후라이', '시래기조림', '베이글'],
#  ['포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '진미채무침',
#   '건새우아욱국',
#   '스크램블에그',
#   '녹두죽',
#   '모닝롤'],
#  ['포기김치', '주스', '사과파이', '검정콩조림', '쌀밥', '흑임자죽', '우유', '차돌박이찌개', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '계란후라이', '시금치국', '프렌치토스트', '모닝롤'],
#  ['고구마줄기볶음', '포기김치', '주스', '쌀밥', '김치죽', '우유', '오징어국', '참치샌드', '계란후라이', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '숙주나물', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['호박죽',
#   '포기김치',
#   '주스',
#   '새송이버섯볶음',
#   '쌀밥',
#   '야채샌드',
#   '우유',
#   '무청된장국',
#   '스크램블에그',
#   '모닝롤'],
#  ['취나물', '포기김치', '주스', '쌀밥', '우유', '동태찌개', '크림누룽지탕', '마늘빵', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '두부김치국', '핫케익', '명엽채무침', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '오이무침', '단호박샌드', '북어국', '수삼닭죽', '계란후라이', '모닝롤'],
#  ['크로와상',
#   '누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '미역줄기볶음',
#   '우유',
#   '호박젓국찌개',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '대구찌개', '도라지나물', '쌀밥', '우유', '에그샌드', '스크램블에그', '쇠고기죽', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '김실파무침', '우유', '땅콩죽', '찐빵', '계란후라이', '감자국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '된장찌개', '쌀밥', '우유', '모닝롤', '김자반', '계란후라이', '베이글'],
#  ['포기김치', '주스', '씨크립샌드', '쌀밥', '우유', '야채죽', '연근조림', '들깨버섯국', '계란후라이', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '콩나물무침', '계란후라이', '열무된장국', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '영양부추생채',
#   '토마토샌드',
#   '스크램블에그',
#   '홍게살죽',
#   '우거지해장국',
#   '모닝롤'],
#  ['포기김치', '주스', '무채국', '쌀밥', '우유', '치즈프레즐', '고구마죽', '시금치나물', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '김치국', '감자조림', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '메론롤케익',
#   '고추장찌개',
#   '쇠고기죽',
#   '계란후라이',
#   '문어꽈리초조림',
#   '모닝롤'],
#  ['치킨샌드',
#   '누룽지탕',
#   '느타리애호박볶음',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '우유',
#   '스크램블에그',
#   '황태국',
#   '모닝롤'],
#  ['멸치볶음', '포기김치', '주스', '쌀밥', '우유', '양송이죽', '애플파이', '차돌박이찌개', '계란후라이', '모닝롤'],
#  ['와플',
#   '포기김치',
#   '주스',
#   '북어해장국',
#   '키위드레싱샐러드',
#   '버섯죽',
#   '쌀밥',
#   '시금치프리타타',
#   '우유',
#   '옥수수스프',
#   '사과',
#   '모닝롤'],
#  ['버섯볶음', '포기김치', '주스', '쌀밥', '잣죽', '우유', '참치샌드', '계란후라이', '감자국', '모닝롤'],
#  ['누룽지탕', '포기김치', '얼갈이나물', '주스', '쌀밥', '우유', '스크램블에그', '카스텔라', '연두부국', '모닝롤'],
#  ['고구마줄기볶음', '포기김치', '주스', '어묵국', '쌀밥', '우유', '새우살죽', '인절미샌드', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '호박새우젓찌개', '고구마파이', '김자반', '계란후라이', '모닝롤'],
#  ['누룽지탕', '근대국', '포기김치', '주스', '쌀밥', '우유', '계란후라이', '명엽채무침', '프렌치토스트', '모닝롤'],
#  ['취나물', '포기김치', '주스', '쌀밥', '우유', '매운버섯국', '해물죽', '햄치즈샌드', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '오징어국', '스크램블에그', '브라우니', '도라지볶음', '모닝롤'],
#  ['포기김치', '주스', '무채국', '쌀밥', '미역줄기볶음', '우유', '바나나샌드', '홍게살죽', '계란후라이', '모닝롤'],
#  ['단팥빵', '포기김치', '주스', '대구찌개', '단호박죽', '쌀밥', '우유', '깻순나물', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '아욱국', '우유', '진미채무침', '찐빵', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '표고버섯죽',
#   '에그샌드',
#   '꽈리고추찜',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤'],
#  ['크로와상', '누룽지탕', '포기김치', '주스', '어묵국', '쌀밥', '우유', '참나물무침', '계란후라이', '모닝롤'],
#  ['얼갈이된장국', '포기김치', '주스', '쌀밥', '야채샌드', '우유', '팥죽', '스크램블에그', '콩나물무침', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '우유', '브로컬리들깨찜', '마늘빵', '계란후라이', '감자국', '모닝롤'],
#  ['누룽지탕', '열무김치', '주스', '쌀밥', '우유', '꿀호떡', '두부김치국', '숙주나물', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '대구찌개', '쌀밥', '우유', '새우살죽', '토마토샌드', '무나물', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '사과파이', '쌀밥', '우유', '연근조림', '선지해장국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '김구이', '쌀밥', '흑임자죽', '우유', '오징어국', '스크램블에그', '옥수수샌드', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '미역줄기볶음', '우유', '야채죽', '재첩국', '시금치팬케익', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '무청된장국', '우유', '김자반', '브라우니', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '우유', '콩조림', '고추장찌개', '참치샌드', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '쇠고기무국', '메론롤케익', '계란후라이', '시래기조림', '모닝롤'],
#  ['포기김치', '주스', '북어해장국', '소라살죽', '쌀밥', '파래무침', '우유', '단호박샌드', '스크램블에그', '모닝롤'],
#  ['소고기죽', '포기김치', '주스', '쌀밥', '우유', '오이무침', '고구마파이', '콩나물국', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '느타리호박볶음',
#   '포기김치',
#   '주스',
#   '어묵국',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '식빵피자', '우유', '매운버섯국', '꽈리고추찜', '견과류죽', '계란후라이', '모닝롤'],
#  ['단팥빵', '포기김치', '주스', '쌀밥', '아욱국', '우유', '크림누룽지탕', '명엽채무침', '계란후라이', '모닝롤'],
#  ['열무나물',
#   '포기김치',
#   '주스',
#   '올챙이만두국',
#   '쌀밥',
#   '우유',
#   '양송이죽',
#   '바나나샌드',
#   '스크램블에그',
#   '모닝롤'],
#  ['김치두부국',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '멸치크랜베리볶음',
#   '우유',
#   '치즈프레즐',
#   '홍게살죽',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '우유', '팬케익', '북어국', '김자반', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '두부조림', '씨크립샌드', '쌀밥', '우유', '꽃게탕', '계란후라이', '모닝롤'],
#  ['와플', '포기김치', '주스', '쌀밥', '우유', '볼어묵볶음', '스크램블에그', '쇠고기죽', '감자국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '마늘쫑볶음', '찐빵', '호박젓국찌개', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '시래기국', '주스', '김구이', '쌀밥', '우유', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '무채국', '쌀밥', '흑임자죽', '우유', '인절미샌드', '동전쥐포무침', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '단배추나물', '쌀밥', '우유', '고구마파이', '오징어국', '계란후라이', '모닝롤'],
#  ['포기김치', '베이컨샌드', '주스', '쌀밥', '우유', '땅콩죽', '연근조림', '스크램블에그', '선지해장국', '모닝롤'],
#  ['멸치볶음', '닭죽', '주스', '쌀밥', '우유', '알타리김치', '꿀호떡', '김치국', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '명엽채무침',
#   '호박젓국찌개',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '검정콩조림', '쌀밥', '우유', '양송이죽', '재첩국', '참치샌드', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '동태탕', '모닝롤', '계란후라이', '시래기조림', '베이글'],
#  ['포기김치', '주스', '쌀밥', '아욱국', '우유', '야채죽', '호박나물', '스크램블에그', '고구마샌드', '모닝롤'],
#  ['크로와상', '포기김치', '주스', '피바지락국', '단호박죽', '쌀밥', '우유', '콩나물무침', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '오이무침', '황태국', '시금치팬케익', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '두부젓국찌개',
#   '에그샌드',
#   '고구마순나물',
#   '홍게살죽',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '감자채햄볶음', '꽃게탕', '브라우니', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '진미채무침', '밤죽', '토마토샌드', '스크램블에그', '감자국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '콩나물김치국', '우유', '메론롤케익', '팥죽', '미역나물', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '녹차호떡', '차돌박이찌개', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '베이컨샌드',
#   '주스',
#   '쌀밥',
#   '콩나물김치국',
#   '우유',
#   '새송이죽',
#   '땅콩멸치볶음',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '우엉조림', '주스', '쌀밥', '우유', '모닝롤', '선지해장국', '계란후라이', '베이글'],
#  ['포기김치',
#   '닭죽',
#   '주스',
#   '쌀밥',
#   '우유',
#   '스크램블에그',
#   '피자토스트',
#   '고추장찌개',
#   '문어꽈리초조림',
#   '모닝롤'],
#  ['포기김치', '주스', '사과파이', '무채국', '쌀밥', '브로컬리초장', '우유', '고구마죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '김자반', '마늘빵', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['포기김치', '주스', '올챙이만두국', '쌀밥', '우유', '야채죽', '인절미샌드', '콩나물무침', '계란후라이', '모닝롤'],
#  ['크로와상', '누룽지탕', '대구매운탕', '주스', '포기김치', '쌀밥', '우유', '아삭고추무침', '계란후라이', '모닝롤'],
#  ['포기김치', '시래기국', '주스', '쌀밥', '우유', '새우살죽', '에그샌드', '스크램블에그', '어묵볶음', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '단배추나물',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '크림누룽지탕',
#   '홍합탕',
#   '프렌치토스트',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '진미채무침', '핫케익', '호박젓국찌개', '계란후라이', '모닝롤'],
#  ['김치두부국', '포기김치', '주스', '쌀밥', '우유', '양송이죽', '꽈리고추찜', '참치샌드', '계란후라이', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '버섯매운탕', '땅콩조림', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '씨크립샌드', '쌀밥', '우유', '김잔파무침', '콩나물국', '스크램블에그', '쇠고기죽', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '멸치크랜베리볶음', '우유', '치즈프레즐', '북어국', '김치죽', '계란후라이', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '브로컬리들깨찜', '계란후라이', '감자국', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '맑은만두육개장',
#   '햄야채샌드',
#   '쌀밥',
#   '우유',
#   '표고버섯죽',
#   '호박나물',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '단호박죽', '쌀밥', '우유', '찐빵', '시금치나물', '차돌박이찌개', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '도라지나물',
#   '쌀밥',
#   '우유',
#   '바나나샌드',
#   '스크램블에그',
#   '고추장찌개',
#   '모닝롤'],
#  ['포기김치', '주스', '피바지락국', '쌀밥', '미역줄기볶음', '우유', '땅콩죽', '모닝롤', '계란후라이', '베이글'],
#  ['누룽지탕', '포기김치', '주스', '명엽채볶음', '쌀밥', '우유', '콩나물국', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '흑임자죽',
#   '우유',
#   '단호박샌드',
#   '버섯매운탕',
#   '감자채햄볶음',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '계란후라이', '매생이굴국', '숙주나물', '프렌치토스트', '모닝롤'],
#  ['포기김치', '베이컨샌드', '주스', '쌀밥', '우유', '팥죽', '스크램블에그', '아삭고추무침', '홍합탕', '모닝롤'],
#  ['포기김치', '주스', '소라살죽', '쌀밥', '우유', '연근조림', '닭개장', '애플파이', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '김잔파무침', '북어국', '꿀호떡', '계란후라이', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '우유', '선지해장국', '감자조림', '옥수수샌드', '계란후라이', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '쌀밥', '치커리유자청무침', '우유', '김치국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '어묵국', '쌀밥', '식빵피자', '우유', '꽈리고추찜', '스크램블에그', '녹두죽', '모닝롤'],
#  ['포기김치', '두부쑥갓무침', '주스', '쌀밥', '우유', '땅콩죽', '고구마파이', '꽃게탕', '계란후라이', '모닝롤'],
#  ['누룽지탕', '쥐포무침', '포기김치', '주스', '쌀밥', '우유', '팬케익', '호박젓국찌개', '계란후라이', '모닝롤'],
#  ['대구매운탕', '포기김치', '주스', '쌀밥', '우유', '야채죽', '토마토샌드', '감자채볶음', '계란후라이', '모닝롤'],
#  ['누룽지탕', '멸치볶음', '포기김치', '주스', '쌀밥', '우유', '쇠고기무국', '브라우니', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '에그샌드', '양송이죽', '스크램블에그', '김자반', '고추장찌개', '모닝롤'],
#  ['포기김치', '미니케익', '주스', '쌀밥', '시금치된장국', '우유', '브로컬리무침', '김치죽', '계란후라이', '모닝롤'],
#  ['김치두부국', '포기김치', '주스', '쌀밥', '잣죽', '우유', '진미채무침', '찐빵', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '북어콩나물국',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '새송이볶음',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '피바지락국',
#   '쌀밥',
#   '우유',
#   '치즈프레즐',
#   '스크램블에그',
#   '견과류죽',
#   '치커리사과무침',
#   '모닝롤'],
#  ['크로와상',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '냉이된장국',
#   '마늘쫑건새우볶음',
#   '해물죽',
#   '계란후라이',
#   '모닝롤'],
#  ['와플', '포기김치', '시래기국', '주스', '쌀밥', '흑임자죽', '우유', '명엽채무침', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '어묵국', '쌀밥', '우유', '에그샌드', '계란후라이', '치커리사과무침', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '우유', '스크램블에그', '선지해장국', '브로컬리들깨찜', '마늘빵', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '매생이굴국',
#   '토마토샌드',
#   '시금치죽',
#   '가지두반장볶음',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '찐빵', '김자반', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['멸치볶음', '포기김치', '주스', '쌀밥', '식빵피자', '우유', '스크램블에그', '견과류죽', '감자국', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '두부쑥갓무침',
#   '주스',
#   '쌀밥',
#   '우유',
#   '바나나샌드',
#   '계란후라이',
#   '유부김치국',
#   '모닝롤'],
#  ['포기김치', '주스', '녹두죽', '쌀밥', '우유', '감자채볶음', '닭개장', '스크램블에그', '시금치핫케익', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '핫도그', '우유', '야채죽', '미역줄기볶음', '콩나물국', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '모닝롤', '감자고추장찌개', '시금치나물', '계란후라이', '베이글'],
#  ['느타리호박볶음',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '스크램블에그',
#   '홍게살죽',
#   '참치샌드',
#   '열무된장국',
#   '모닝롤'],
#  ['단팥빵', '누룽지탕', '대구매운탕', '주스', '포기김치', '쌀밥', '우유', '아삭고추무침', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '브로컬리죽',
#   '주스',
#   '검정콩조림',
#   '쌀밥',
#   '야채샌드',
#   '우유',
#   '스크램블에그',
#   '호박젓국찌개',
#   '모닝롤'],
#  ['포기김치', '주스', '피바지락국', '쌀밥', '우유', '꿀호떡', '팥죽', '고구마순볶음', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '두부양념조림',
#   '우유',
#   '쇠고기무국',
#   '후르츠팬케익',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치',
#   '베이컨샌드',
#   '주스',
#   '쌀밥',
#   '우유',
#   '양송이죽',
#   '꽈리고추찜',
#   '스크램블에그',
#   '조랭이미역국',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '사과파이', '쌀밥', '우유', '홍합탕', '계란후라이', '시래기조림', '모닝롤'],
#  ['포기김치',
#   '달래된장찌개',
#   '주스',
#   '쌀밥',
#   '우유',
#   '땅콩죽',
#   '김잔파무침',
#   '스크램블에그',
#   '햄치즈샌드',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '톳두부무침', '메론롤케익', '해물죽', '계란후라이', '감자국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '꽃게탕', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '매생이떡국',
#   '크림누룽지탕',
#   '스크램블에그',
#   '카레감자볶음',
#   '옥수수샌드',
#   '모닝롤'],
#  ['와플', '누룽지탕', '콩가루배추국', '주스', '포기김치', '쌀밥', '우유', '명엽채무침', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '피바지락국',
#   '쌀밥',
#   '흑임자죽',
#   '우유',
#   '마늘쫑건새우무침',
#   '바나나샌드',
#   '스크램블에그',
#   '모닝롤'],
#  ['호박죽', '포기김치', '주스', '맑은만두육개장', '쌀밥', '우유', '찐빵', '곰피초장', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '핫케익', '황태국', '계란후라이', '애호박나물', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '우유', '에그샌드', '스크램블에그', '선지해장국', '김자반', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '브로컬리들깨찜', '브라우니', '계란후라이', '연두부국', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '마늘쫑무침',
#   '쌀밥',
#   '우유',
#   '양송이죽',
#   '쇠고기미역국',
#   '스크램블에그',
#   '고구마샌드',
#   '모닝롤'],
#  ['크로와상', '포기김치', '주스', '쌀밥', '우유', '오징어국', '꽈리고추찜', '김치죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '계란후라이', '숙주나물', '봄동된장국', '프렌치토스트', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '도라지나물',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '새우살죽',
#   '스크램블에그',
#   '북어계란국',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '땅콩죽', '고구마파이', '콩나물국', '어묵볶음', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '시래기된장국',
#   '쌀밥',
#   '우유',
#   '진미채무침',
#   '모카카스테라',
#   '계란후라이',
#   '베이글'],
#  ['포기김치', '주스', '단배추나물', '쌀밥', '잣죽', '우유', '토마토샌드', '스크램블에그', '민물새우찌개', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '꽃게탕', '감자채볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '우엉조림', '주스', '쌀밥', '식빵피자', '우유', '느타리버섯국', '스크램블에그', '녹두죽', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '야채죽', '가지나물', '팥호빵', '호박젓국찌개', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '사과파이', '쌀밥', '우유', '계란후라이', '애호박나물', '쑥국', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '올챙이만두국',
#   '쌀밥',
#   '우유',
#   '땅콩죽',
#   '바나나샌드',
#   '스크램블에그',
#   '브로컬리들깨찜',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '메론롤케익', '시금치나물', '계란후라이', '바지락국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '팥죽', '명엽채무침', '옥수수샌드', '계란후라이', '감자국', '모닝롤'],
#  ['누룽지탕', '포기김치', '시래기국', '주스', '쌀밥', '우유', '오이무침', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '우유', '에그샌드', '스크램블에그', '선지해장국', '쑥갓두부무침', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '초코핫케익',
#   '쌀밥',
#   '우유',
#   '크렌베리멸치볶음',
#   '고추장찌개',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '단호박죽', '무채국', '쌀밥', '우유', '스크램블에그', '콩나물무침', '고구마샌드', '모닝롤'],
#  ['크로와상', '포기김치', '주스', '쌀밥', '우유', '오징어국', '해물죽', '김자반', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '브로컬리초장', '우유', '찐빵', '호박젓국찌개', '계란후라이', '모닝롤'],
#  ['느타리호박볶음', '포기김치', '주스', '쌀밥', '우유', '야채죽', '모닝롤', '스크램블에그', '황태국', '베이글'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '단호박샌드',
#   '아삭고추무침',
#   '조랭이미역국',
#   '계란후라이',
#   '모닝롤'],
#  ['단팥빵', '근대국', '포기김치', '주스', '쌀밥', '잣죽', '우유', '김잔파무침', '스크램블에그', '모닝롤'],
#  ['취나물', '김치콩나물국', '주스', '포기김치', '단호박죽', '쌀밥', '우유', '참치샌드', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '두부조림', '쌀밥', '우유', '계란후라이', '프렌치토스트', '감자국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '흑임자죽', '미역줄기볶음', '스크램블에그', '꽃게탕', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '대구찌개', '도라지나물', '쌀밥', '우유', '모카카스테라', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '씨크립샌드', '쌀밥', '아욱국', '우유', '진미채무침', '양송이죽', '스크램블에그', '모닝롤'],
#  ['포기김치', '주스', '검정콩조림', '쌀밥', '우유', '고구마파이', '고추장찌개', '녹두죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '마늘빵', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '무채국', '쌀밥', '우유', '스크램블에그', '고구마샌드', '문어꽈리초조림', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '시금치나물', '조랭이떡국', '계란후라이', '모닝롤'],
#  ['멸치볶음', '포기김치', '주스', '인절미토스트', '쌀밥', '우유', '냉이된장국', '스크램블에그', '김치죽', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '고구마파이', '청포묵무침', '오징어국', '견과류죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '연근조림', '미역국', '모닝롤', '계란후라이', '베이글'],
#  ['콩가루배추국',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '해물죽',
#   '스크램블에그',
#   '햄치즈샌드',
#   '감자채볶음',
#   '모닝롤'],
#  ['크로와상', '누룽지탕', '김치콩나물국', '주스', '포기김치', '쌀밥', '우유', '계란후라이', '모둠묵*장', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '팥죽', '바나나샌드', '스크램블에그', '선지해장국', '가지나물', '모닝롤'],
#  ['포기김치', '주스', '사과파이', '쌀밥', '우유', '김잔파무침', '황태국', '계란후라이', '참치야채죽', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '시금치된장국',
#   '우유',
#   '계란후라이',
#   '명엽채무침',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '느타리볶음', '쌀밥', '우유', '표고버섯죽', '스크램블에그', '참치샌드', '감자국', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '브로컬리초장',
#   '우유',
#   '들깨시래기국',
#   '브라우니',
#   '계란후라이',
#   '모닝롤'],
#  ['취나물', '포기김치', '주스', '쌀밥', '우유', '땅콩죽', '에그샌드', '두부젓국찌개', '스크램블에그', '모닝롤'],
#  ['김치두부국', '포기김치', '주스', '쌀밥', '우유', '팬케익', '김자반', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '찐빵', '숙주나물', '북어계란국', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '야채샌드',
#   '우유',
#   '옹심이만두떡국',
#   '스크램블에그',
#   '고구마죽',
#   '어묵볶음',
#   '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '대구찌개', '비름나물', '쌀밥', '우유', '계란후라이', '모닝롤'],
#  ['마늘쫑새우볶음',
#   '포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '스크램블에그',
#   '고추장찌개',
#   '녹두죽',
#   '모닝롤'],
#  ['호박죽', '포기김치', '주스', '쌀밥', '우유', '오징어국', '꿀호떡', '콩나물무침', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '계란후라이', '프렌치토스트', '감자국', '모닝롤'],
#  ['포기김치', '주스', '도토리묵무침', '쌀밥', '우유', '야채죽', '들깨버섯국', '스크램블에그', '참치샌드', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '아욱된장국', '롤케익', '계란후라이', '감자채피망볶음', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '단호박샌드', '팥죽', '콩자반', '스크램블에그', '꽃게탕', '모닝롤'],
#  ['와플', '포기김치', '주스', '쌀밥', '잣죽', '우유', '냉이된장국', '진미채무침', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '북어해장국', '쌀밥', '우유', '마늘빵', '계란후라이', '애호박나물', '모닝롤'],
#  ['누룽지탕', '떡국', '포기김치', '주스', '쌀밥', '우유', '고구마파이', '숙주나물', '계란후라이', '모닝롤'],
#  ['멸치볶음', '포기김치', '주스', '참치죽', '호밧젓국찌개', '쌀밥', '우유', '바나나샌드', '스크램블에그', '모닝롤'],
#  ['크로와상',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '콩나물김치국',
#   '우유',
#   '새우살죽',
#   '브로컬리*초장',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕', '들깨미역국', '포기김치', '주스', '쌀밥', '핫도그', '우유', '스크램블에그', '아삭고추무침', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '표고버섯죽',
#   '치즈프레즐',
#   '김가루실파무침',
#   '계란후라이',
#   '열무된장국',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '흑임자죽',
#   '우유',
#   '매운버섯국',
#   '마늘쫑볶음',
#   '스크램블에그',
#   '옥수수샌드',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '오이사과무침', '북어계란국', '브라우니', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '어묵국', '쌀밥', '우유', '팬케익', '땅콩조림', '계란후라이', '모닝롤'],
#  ['호박죽', '포기김치', '주스', '쌀밥', '우유', '쇠고기무국', '스크램블에그', '카스텔라', '가지나물', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '오징어국', '모닝롤', '쑥갓두부무침', '계란후라이', '베이글'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '양송이죽',
#   '스크램블에그',
#   '선지해장국',
#   '브로컬리들깨찜',
#   '햄치즈샌드',
#   '모닝롤'],
#  ['포기김치', '주스', '사과파이', '쌀밥', '우유', '동태탕', '명엽채무침', '녹두죽', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '도라지나물',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '북어계란국',
#   '프렌치토스트',
#   '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '마늘쫑무침', '쌀밥', '우유', '계란후라이', '감자국', '모닝롤'],
#  ['포기김치',
#   '닭죽',
#   '주스',
#   '김치순두부찌개',
#   '쌀밥',
#   '우유',
#   '도토리묵*장',
#   '스크램블에그',
#   '참치샌드',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '흑임자죽',
#   '우유',
#   '메론롤케익',
#   '꽈리고추찜',
#   '소고기미역국',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '진미채볶음', '마늘빵', '계란후라이', '열무된장국', '모닝롤'],
#  ['포기김치', '우엉조림', '주스', '쌀밥', '잣죽', '우유', '인절미샌드', '스크램블에그', '황태국', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '맑은만두육개장',
#   '쌀밥',
#   '우유',
#   '참나물땅콩무침',
#   '꿀호떡',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '콩나물김치국',
#   '우유',
#   '단호박샌드',
#   '해물죽',
#   '스크램블에그',
#   '감자채볶음',
#   '모닝롤'],
#  ['크로와상', '포기김치', '주스', '버섯죽', '쌀밥', '우유', '숙주나물', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '시금치된장국', '우유', '구운어묵볶음', '찐빵', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '김구이', '쌀밥', '야채샌드', '우유', '꽃게탕', '스크램블에그', '견과류죽', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '야채죽',
#   '아삭고추무침',
#   '호박젓국찌개',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '아욱국', '우유', '고구마파이', '청포묵무침', '김치죽', '계란후라이', '모닝롤'],
# ...
#  ['열무김치', '주스', '오징어젓갈무침', '쌀밥', '잣죽', '우유', '미역국', '햄치즈샌드', '계란후라이', '모닝롤'],
#  ['와플', '포기김치', '주스', '쌀밥', '우유', '감자조림', '고구마죽', '어묵탕', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '김가루잔파무침',
#   '쌀밥',
#   '우유',
#   '치즈프레즐',
#   '들깨시래기국',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '두부쑥갓무침', '주스', '쌀밥', '식빵피자', '우유', '땅콩죽', '호박젓국찌개', '계란후라이', '모닝롤'],
#  ['호박죽',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '청포묵무침',
#   '찐빵',
#   '없이)',
#   '(샐러드닭가슴살',
#   '스크램블에그',
#   '차돌박이찌개',
#   '모닝롤'],
#  ['누룽지탕', '베이컨샌드', '주스', '열무김치', '쌀밥', '우유', '맑은만두국', '깻순나물', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '꽈리고추찜', '호떡', '해물죽', '계란후라이', '감자국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '황태국', '쌀밥', '우유', '진미채무침', '스크램블에그', '마늘빵', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '새우살죽', '에그샌드', '미역국', '스크램블에그', '아삭고추무침', '모닝롤'],
#  ['누룽지탕', '대구매운탕', '포기김치', '주스', '쌀밥', '우유', '모닝롤', '어묵볶음', '계란후라이', '베이글'],
#  ['멸치볶음', '포기김치', '주스', '무채국', '쌀밥', '우유', '야채죽', '팥호빵', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '계란후라이', '연두부탕', '명엽채무침', '프렌치토스트', '모닝롤'],
#  ['포기김치', '주스', '씨크립샌드', '쌀밥', '우유', '스크램블에그', '고구마죽', '시금치국', '가지나물', '모닝롤'],
#  ['크로와상', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '오징어국', '김자반', '계란후라이', '모닝롤'],
#  ['근대국', '포기김치', '주스', '쌀밥', '잣죽', '우유', '토마토샌드', '계란후라이', '문어꽈리초조림', '모닝롤'],
#  ['열무나물', '포기김치', '주스', '우거지해장국', '쌀밥', '우유', '팥죽', '계란후라이', '허니브레드', '모닝롤'],
#  ['누룽지탕', '들깨미역국', '포기김치', '주스', '쌀밥', '우유', '진미채볶음', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '우유', '스크램블에그', '시금치나물', '꽃게탕', '참치샌드', '모닝롤'],
#  ['누룽지탕',
#   '멸치볶음',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '해물순두부찌개',
#   '애플잼쿠키',
#   '계란후라이',
#   '모닝롤'],
#  ['호박죽', '포기김치', '주스', '쌀밥', '우유', '옥수수샌드', '감자채볶음', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['와플', '포기김치', '주스', '비름나물', '쌀밥', '우유', '야채죽', '차돌박이찌개', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '시래기국', '주스', '김구이', '쌀밥', '우유', '핫케익', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '콩나물국', '스크램블에그', '무나물', '햄치즈샌드', '모닝롤'],
#  ['누룽지탕',
#   '콩가루배추국',
#   '포기김치',
#   '주스',
#   '알감자조림',
#   '쌀밥',
#   '우유',
#   '고구마파이',
#   '계란후라이',
#   '모닝롤'],
#  ['치킨샌드', '포기김치', '주스', '쌀밥', '우유', '오징어국', '참나물생채', '녹두죽', '계란후라이', '모닝롤'],
#  ['소고기죽', '포기김치', '우엉조림', '주스', '쌀밥', '우유', '모닝롤', '감자고추장찌개', '계란후라이', '베이글'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '느타리볶음',
#   '쌀밥',
#   '우유',
#   '두부젓국찌개',
#   '시금치핫케익',
#   '계란후라이',
#   '모닝롤'],
#  ['호박죽', '포기김치', '주스', '무채국', '쌀밥', '야채샌드', '우유', '건새우마늘쫑볶음', '스크램블에그', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '진미채무침', '꽃게탕', '계란후라이', '모닝롤'],
#  ['포기김치', '감자샌드', '주스', '쌀밥', '잣죽', '우유', '미역줄기볶음', '콩나물국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '황태국', '쌀밥', '우유', '해물죽', '호박채나물', '롤케익', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '쇠고기무국',
#   '김잔파무침',
#   '프렌치토스트',
#   '모닝롤'],
#  ['시금치나물',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '표고버섯죽',
#   '스크램블에그',
#   '고추장찌개',
#   '고구마샌드',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '사과파이', '쌀밥', '브로컬리초장', '우유', '동태탕', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '새우살죽', '바나나샌드', '멸치아몬드볶음', '계란후라이', '감자국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '핫도그', '우유', '매운버섯국', '깻순나물', '견과류죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '무채국', '쌀밥', '우유', '핫케이크', '김자반', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '야채죽', '스크램블에그', '조랭이떡국', '가지나물', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '연두부탕', '꿀호떡', '명엽채무침', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '인절미샌드', '영양부추생채', '녹두죽', '계란후라이', '열무된장국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '연근조림', '찐빵', '콩나물국', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '김잔파무침', '호박젓국찌개', '마늘빵', '계란후라이', '모닝롤'],
#  ['동전문어조림', '포기김치', '닭죽', '주스', '쌀밥', '우유', '스크램블에그', '홍루이젠', '감자국', '모닝롤'],
#  ['누룽지탕', '포기김치', '시래기국', '주스', '쌀밥', '우유', '고구마파이', '감자조림', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '올챙이만두국', '쌀밥', '식빵피자', '우유', '해물죽', '어묵볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '우유', '쇠고기샤브국', '카스텔라', '계란후라이', '애호박나물', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '북어해장국',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '진미채무침',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '우유', '에그샌드', '두부김치국', '스크램블에그', '깻순나물', '모닝롤'],
#  ['누룽지탕', '멸치볶음', '포기김치', '주스', '쌀밥', '우유', '단호박찐빵', '계란후라이', '열무된장국', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '표고버섯죽',
#   '노각무침',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤'],
#  ['포기김치', '주스', '사과파이', '쌀밥', '우유', '땅콩조림', '홍게살죽', '계란후라이', '우거지해장국', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '아삭고추무침', '조랭이떡국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '김잔파무침', '스크램블에그', '참치샌드', '녹두죽', '감자국', '모닝롤'],
#  ['크로와상', '누룽지탕', '포기김치', '주스', '느타리볶음', '쌀밥', '우유', '새우살미역국', '계란후라이', '모닝롤'],
#  ['호박죽', '포기김치', '주스', '쌀밥', '우유', '가지나물', '토마토샌드', '계란후라이', '연두부국', '모닝롤'],
#  ['쥐포무침', '포기김치', '주스', '쌀밥', '우유', '쇠고기무국', '치즈프레즐', '김치죽', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '사과잼쿠키',
#   '두부김치국',
#   '오이맛살냉채',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '무채국', '쌀밥', '우유', '팥죽', '스크램블에그', '옥수수샌드', '고구마줄기볶음', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '동태탕', '소시지감자볶음', '계란후라이', '모닝롤'],
#  ['근대국', '포기김치', '주스', '쌀밥', '우유', '볼어묵볶음', '찐빵', '해물죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '핫케이크', '오징어국', '김자반', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '흑임자죽', '식빵피자', '우유', '연근조림', '스크램블에그', '호박새우젓국', '모닝롤'],
#  ['누룽지탕', '포기김치', '두부쑥갓무침', '주스', '쌀밥', '우유', '롤케익', '계란후라이', '만두국', '모닝롤'],
#  ['연두부찌개', '포기김치', '주스', '쌀밥', '우유', '야채죽', '마늘쫑볶음', '바나나샌드', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '된장찌개', '쌀밥', '잣죽', '우유', '고구마파이', '실곤약흑임자무침', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '명엽채무침', '마늘빵', '계란후라이', '감자국', '모닝롤'],
#  ['포기김치', '주스', '어묵국', '쌀밥', '우유', '단호박샌드', '꽈리고추찜', '스크램블에그', '김치죽', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '핫도그', '우유', '메추리알조림', '계란후라이', '열무된장국', '모닝롤'],
#  ['단팥빵',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '새우살야채죽',
#   '황태해장국',
#   '오이사과무침',
#   '계란후라이',
#   '모닝롤'],
#  ['대구매운탕', '포기김치', '주스', '느타리볶음', '쌀밥', '우유', '꿀호떡', '녹두죽', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '조랭이떡미역국',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '동전쥐포무침',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '땅콩죽', '김잔파무침', '두부김치국', '스크램블에그', '옥수수샌드', '모닝롤'],
#  ['와플', '누룽지탕', '시래기국', '주스', '포기김치', '쌀밥', '우유', '감자채볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '야채죽', '가지나물', '오징어국', '참치샌드', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '맑은만두육개장', '쌀밥', '우유', '찐빵', '영양부추생채', '해물죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '떡국', '포기김치', '주스', '쌀밥', '비트무생채', '우유', '녹차호떡', '계란후라이', '모닝롤'],
#  ['포기김치', '감자샌드', '주스', '쌀밥', '잣죽', '우유', '연근조림', '스크램블에그', '열무된장국', '모닝롤'],
#  ['누룽지탕', '포기김치', '얼갈이나물', '주스', '사과파이', '쌀밥', '우유', '계란후라이', '감자국', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '시래기국',
#   '주스',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '두반장가지볶음',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '순두부국', '검정콩조림', '쌀밥', '우유', '새우살죽', '에그샌드', '스크램블에그', '모닝롤'],
#  ['누룽지탕', '포기김치', '우엉조림', '주스', '사과파이', '쌀밥', '우유', '차돌박이찌개', '계란후라이', '모닝롤'],
#  ['멸치볶음', '포기김치', '주스', '쌀밥', '흑임자죽', '우유', '단호박샌드', '계란후라이', '감자국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '야채죽', '닭개장', '도토리묵*장', '시금치팬케익', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '진미채무침', '배추된장국', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '씨크립샌드', '김구이', '쌀밥', '우유', '스크램블에그', '고구마죽', '대구탕', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '오징어국', '계란후라이', '시래기조림', '모닝롤'],
#  ['느타리호박볶음',
#   '들깨미역국',
#   '포기김치',
#   '주스',
#   '대만샌드위치',
#   '쌀밥',
#   '우유',
#   '땅콩죽',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '두부쑥갓무침', '주스', '참치죽', '된장찌개', '쌀밥', '우유', '카스텔라', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '찐빵', '꽈리고추찜', '콩나물국', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '핫도그', '우유', '소고기무국', '땅콩조림', '계란후라이', '모닝롤'],
#  ['쥐포무침', '포기김치', '주스', '쌀밥', '우유', '치즈프레즐', '홍게살죽', '황태국', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '꿀호떡', '명엽채무침', '계란후라이', '감자국', '모닝롤'],
#  ['근대국', '포기김치', '주스', '쌀밥', '미역줄기볶음', '우유', '바나나샌드', '쇠고기죽', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '크림누룽지탕',
#   '호박젓국찌개',
#   '김자반',
#   '옥수수샌드',
#   '계란후라이',
#   '모닝롤'],
#  ['크로와상', '취나물', '닭죽', '주스', '포기김치', '쌀밥', '우유', '계란후라이', '바지락국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '무생채', '쌀밥', '우유', '얼갈이국', '찐빵', '계란후라이', '모닝롤'],
#  ['조랭이떡미역국',
#   '멸치볶음',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '야채죽',
#   '스크램블에그',
#   '고구마샌드',
#   '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '오징어국', '계란후라이', '모닝롤'],
#  ['포기김치', '시래기국', '주스', '쌀밥', '참치새드', '우유', '연근땅콩조림', '팥죽', '계란후라이', '모닝롤'],
#  ['김치두부국', '포기김치', '주스', '도라지나물', '쌀밥', '우유', '땅콩죽', '애플파이', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '김치콩나물국', '주스', '쌀밥', '우유', '녹차호떡', '김자반', '계란후라이', '모닝롤'],
#  ['포기김치', '두부쑥갓무침', '주스', '쌀밥', '야채샌드', '우유', '잣죽', '소고기무국', '스크램블에그', '모닝롤'],
#  ['크로와상', '누룽지탕', '포기김치', '주스', '무채국', '쌀밥', '우유', '꽈리고추찜', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '식빵피자', '우유', '꽃게된장국', '동전쥐포무침', '김치죽', '계란후라이', '모닝롤'],
#  ['열무나물', '포기김치', '주스', '쌀밥', '흑임자죽', '우유', '롤케익', '계란후라이', '감자국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '두부김치국', '땅콩조림', '마늘빵', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '베이컨샌드',
#   '주스',
#   '쌀밥',
#   '우유',
#   '진미채무침',
#   '스크램블에그',
#   '홍게살죽',
#   '배추된장국',
#   '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '오렌지케익빵',
#   '황태국',
#   '계란후라이',
#   '문어꽈리초조림',
#   '모닝롤'],
#  ['단팥빵', '포기김치', '주스', '쌀밥', '아욱국', '우유', '어묵볶음', '견과류죽', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '인기가요샌드', '쌀밥', '우유', '재첩국', '녹두죽', '계란후라이', '시래기조림', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '핫도그', '우유', '미역줄기볶음', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '야채죽', '에그샌드', '스크램블에그', '가지나물', '연두부국', '모닝롤'],
#  ['와플', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '연근조림', '대구탕', '계란후라이', '모닝롤'],
#  ['소고기죽',
#   '포기김치',
#   '주스',
#   '피바지락국',
#   '도토리묵무침',
#   '쌀밥',
#   '우유',
#   '토마토샌드',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '참치죽', '쌀밥', '우유', '메론롤케익', '명엽채무침', '계란후라이', '감자국', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '초코핫케익', '쌀밥', '우유', '미역국', '아삭고추무침', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '북어해장국', '쌀밥', '잣죽', '우유', '연근조림', '스크램블에그', '고구마샌드', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '찐빵', '김자반', '조랭이떡국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '된장찌개', '쌀밥', '우유', '해물죽', '참치샌드', '계란후라이', '시래기조림', '모닝롤'],
#  ['포기김치', '주스', '어묵국', '쌀밥', '무생채', '우유', '팥죽', '애플파이', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '배추시래기국', '호빵', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '꽃게된장찌개',
#   '쌀밥',
#   '우유',
#   '땅콩죽',
#   '스크램블에그',
#   '옥수수샌드',
#   '감자채볶음',
#   '모닝롤'],
#  ['누룽지탕', '무비트생채', '포기김치', '주스', '크림치즈프레즐', '쌀밥', '우유', '홍합탕', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '볼어묵조림', '우유', '야채죽', '에그샌드', '닭곰탕', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '콩가루된장국', '우유', '시금치나물', '카스텔라', '김치죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '쥐포무침', '포기김치', '주스', '쌀밥', '우유', '오렌지케익빵', '콩나물국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '스크램블에그', '쑥갓두부무침', '쇠고기죽', '감자국', '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '무채국', '쌀밥', '우유', '계란후라이', '문어꽈리초조림', '모닝롤'],
#  ['호박죽', '포기김치', '주스', '쌀밥', '미역줄기볶음', '우유', '토마토샌드', '황태국', '계란후라이', '모닝롤'],
#  ['크로와상', '포기김치', '주스', '참치죽', '쌀밥', '우유', '순두부찌개', '숙주나물', '계란후라이', '모닝롤'],
#  ['누룽지탕', '느타리호박볶음', '포기김치', '주스', '쌀밥', '우유', '핫케익', '대구탕', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '올갱이아욱국',
#   '명엽채무침',
#   '스크램블에그',
#   '견과류죽',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '꽃게탕', '애플파이', '감자채볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '얼갈이나물', '주스', '소라살죽', '쌀밥', '어묵국', '식빵피자', '우유', '계란후라이', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '우유', '김자반', '배추된장국', '마늘빵', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '된장찌개',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '사과오이초무침',
#   '프렌치토스트',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '연근조림', '인절미샌드', '콩나물국', '스크램블에그', '녹두죽', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '고구마파이',
#   '두부떡국',
#   '느타리버섯볶음',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '해물죽', '소시지볶음', '계란후라이', '바지락국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '야채죽', '찐빵', '얼갈이겉절이', '닭곰탕', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '맑은순두부국', '야채호빵', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '우유', '콩나물국', '스크램블에그', '고구마샌드', '시래기조림', '모닝롤'],
#  ['크로와상',
#   '누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '미역줄기볶음',
#   '우유',
#   '차돌박이된장찌개',
#   '계란후라이',
#   '모닝롤'],
#  ['우엉간장조림', '포기김치', '주스', '쌀밥', '우유', '바나나샌드', '계란후라이', '참치야채죽', '만두국', '모닝롤'],
#  ['소고기죽',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '동태찌개',
#   '카스텔라',
#   '느타리버섯장조림',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '어묵꽈리고추볶음', '주스', '쌀밥', '우유', '꿀호떡', '순두부탕', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '새우살죽', '에그샌드', '진미채무침', '스크램블에그', '꽃게탕', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '미역국', '크림누룽지탕', '옥수수샌드', '감자채볶음', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '홍게살죽',
#   '홍합탕',
#   '멸치아몬드볶음',
#   '시금치핫케익',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '콩나물김치국', '우유', '계란후라이', '김자반', '프렌치토스트', '모닝롤'],
#  ['포기김치',
#   '두부쑥갓무침',
#   '주스',
#   '쌀밥',
#   '야채샌드',
#   '우유',
#   '스크램블에그',
#   '고구마죽',
#   '열무된장국',
#   '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '콩나물무침', '북어계란국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '단호박죽', '쌀밥', '미역줄기볶음', '우유', '찐빵', '대구탕', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '연두부탕', '핫케익', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '씨크립샌드', '쌀밥', '우유', '매생이떡국', '숙주나물', '스크램블에그', '견과류죽', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '어묵국', '쌀밥', '우유', '애플파이', '감자채볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '북어해장국', '소라살죽', '쌀밥', '두부양념조림', '식빵피자', '우유', '계란후라이', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '우유', '연근조림', '콩비지찌개', '케익', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '김자반', '고추장찌개', '카스텔라', '계란후라이', '모닝롤'],
#  ['멸치볶음', '감자양파국', '포기김치', '주스', '쌀밥', '흑임자죽', '우유', '바나나샌드', '스크램블에그', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '볼어묵조림',
#   '우유',
#   '치즈프레즐',
#   '차돌박이찌개',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '우엉조림', '주스', '쌀밥', '우유', '옥수수샌드', '조랭이떡국', '녹두죽', '계란후라이', '모닝롤'],
#  ['연두부*장', '포기김치', '주스', '무채국', '쌀밥', '우유', '꿀호떡', '팥죽', '계란후라이', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '핫도그', '우유', '오징어국', '명엽채무침', '계란후라이', '모닝롤'],
#  ['와플', '봄동겉절이', '포기김치', '주스', '쌀밥', '우유', '표고버섯죽', '동태탕', '스크램블에그', '모닝에그빵'],
#  ['크로와상', '누룽지탕', '딤섬', '주스', '포기김치', '쌀밥', '우유', '재첩국', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '크래미숙주무침',
#   '우유',
#   '땅콩죽',
#   '토마토샌드',
#   '피바지락배추국',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕', '김치두부국', '쥐포무침', '주스', '포기김치', '쌀밥', '우유', '팬케익', '계란후라이', '베이글'],
#  ['포기김치', '주스', '쌀밥', '야채샌드', '우유', '미역줄기볶음', '스크램블에그', '고구마죽', '꽃게탕', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '오징어젓갈무침', '쌀밥', '우유', '호빵', '계란후라이', '감자국', '모닝롤'],
#  ['느타리호박볶음', '포기김치', '대구탕', '주스', '쌀밥', '잣죽', '우유', '참치샌드', '계란후라이', '모닝롤'],
#  ['소보루빵', '누룽지탕', '포기김치', '주스', '김구이', '쌀밥', '우유', '시금치국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '된장찌개', '쌀밥', '우유', '진미채무침', '양송이죽', '피자빵', '스크램블에그', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '초코핫케익', '쌀밥', '우유', '땅콩조림', '계란후라이', '만두국', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '흑임자죽',
#   '우유',
#   '마늘쫑볶음',
#   '호박젓국찌개',
#   '햄치즈샌드',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치',
#   '주스',
#   '쌀밥',
#   '김치도토리묵무침',
#   '우유',
#   '야채죽',
#   '고구마파이',
#   '소고기무국',
#   '계란후라이',
#   '모닝롤'],
#  ['누룽지탕',
#   '주스',
#   '쌀밥',
#   '우유',
#   '새우살미역국',
#   '통아몬드멸치볶음',
#   '배추겉절이',
#   '롤케익',
#   '계란후라이',
#   '모닝롤'],
#  ['떡국', '포기김치', '주스', '알감자조림', '쌀밥', '우유', '에그샌드', '스크램블에그', '녹두죽', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '사과파이', '무채국', '쌀밥', '두부양념조림', '우유', '계란후라이', '모닝롤'],
#  ['포기김치',
#   '북어맑은국',
#   '주스',
#   '쌀밥',
#   '야채샌드',
#   '우유',
#   '크림누룽지탕',
#   '참나물무침',
#   '계란후라이',
#   '모닝롤'],
#  ['호박죽', '포기김치', '주스', '쌀밥', '우유', '꿀호떡', '꽃게탕', '숙주나물무침', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '김치두부국',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '계란후라이',
#   '꽈리고추찜',
#   '프렌치토스트',
#   '모닝롤'],
#  ['얼갈이된장국',
#   '쥐포무침',
#   '포기김치',
#   '주스',
#   '씨크립샌드',
#   '쌀밥',
#   '우유',
#   '스크램블에그',
#   '견과류죽',
#   '모닝롤'],
#  ['단팥빵', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '김잔파무침', '오징어국', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '새우살죽', '볼어묵볶음', '참치샌드', '계란후라이', '감자국', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '팥죽', '버섯매운탕', '땅콩조림', '마늘빵', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '쌀밥',
#   '우유',
#   '명엽채무침',
#   '시금치팬케익',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '잣죽', '식빵피자', '우유', '봄동된장국', '스크램블에그', '시금치초무침', '모닝롤'],
#  ['누룽지탕', '포기김치', '주스', '쌀밥', '우유', '고구마파이', '홍합탕', '감자채볶음', '계란후라이', '모닝롤'],
#  ['포기김치', '주스', '쌀밥', '우유', '연두부탕', '가지나물', '토마토샌드', '홍게살죽', '계란후라이', '모닝롤'],
#  ['포기김치', '닭죽', '주스', '쌀밥', '우유', '호박젓국찌개', '김자반', '카스텔라', '계란후라이', '모닝롤'],
#  ['누룽지탕',
#   '포기김치',
#   '주스',
#   '무채국',
#   '쌀밥',
#   '우유',
#   '찐빵',
#   '연두부*참깨드레싱소스',
#   '계란후라이',
#   '모닝롤'],
#  ['포기김치', '감자샌드', '주스', '쌀밥', '우유', '꽈리고추멸치볶음', '스크램블에그', '황태국', '녹두죽', '모닝롤'],
#  ['크로와상', '누룽지탕', '포기김치', '주스', '쌀밥', '우유', '감자조림', '계란후라이', '연두부국', '모닝롤'],
#  ['포기김치',
#   '주스',
#   '맑은만두육개장',
#   '쌀밥',
#   '우유',
#   '에그샌드',
#   '해물죽',
#   '숙주나물무침',
#   '계란후라이',
#   '모닝롤'],
#  ...]

# %%
food_all = [element for array in food_combinations for element in array]

# %%
food_all2 = list(set(food_all))

# %%
with open("menu.txt", "w") as output:
    output.write(str(food_all2))

# %%
train.head()
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
# 2  2016-02-03  수   2601      56     180             111          0.0
# 3  2016-02-04  목   2601     104     220             355          0.0
# 4  2016-02-05  금   2601     278     181              34          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
# 2  모닝롤/베이글  우유/두유/주스 계란후라이  표고버섯죽/쌀밥 (쌀:국내산) 콩나물국...
# 3  모닝롤/토마토샌드  우유/두유/주스 계란후라이  닭죽/쌀밥 (쌀,닭:국내산) 근대국...
# 4  모닝롤/와플  우유/두유/주스 계란후라이  쇠고기죽/쌀밥 (쌀:국내산) 재첩국  방...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
# 2  카레덮밥 (쌀,현미흑미:국내산) 팽이장국  치킨핑거 (닭고기:국내산) 쫄면야채무침 ...
# 3  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 쇠고기무국  주꾸미볶음  부추전  시금치나물  ...
# 4  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 떡국  돈육씨앗강정 (돼지고기:국내산) 우엉잡채...
#
#                                                 석식메뉴     중식계    석식계  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0
# 2  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 청국장찌개  황태양념구이 (황태:러시아산) 고기...  1017.0  573.0
# 3  미니김밥*겨자장 (쌀,현미흑미:국내산) 우동  멕시칸샐러드  군고구마  무피클  포...   978.0  525.0
# 4  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 차돌박이찌개 (쇠고기:호주산) 닭갈비 (닭고기:...   925.0  330.0
#
#                                           조식메뉴2
# 0    [건파래무침, 포기김치, 두부조림, 쌀밥, 잡곡밥, 자반고등어구이, 육개장]
# 1       [콩나물밥*양념장, 포기김치, 어묵국, 바나나, 유산슬, 아삭고추무침]
# 2  [포기김치, 새송이버섯볶음, 쌀밥, 잡곡밥, 청국장찌개, 황태양념구이, 고기전]
# 3       [군고구마, 우동, 포기김치, 미니김밥*겨자장, 멕시칸샐러드, 무피클]
# 4  [포기김치, 닭갈비, 쌀밥, 잡곡밥, 감자소세지볶음, 콩나물무침, 차돌박이찌개]

# %%
# HYPER PARAMETERS

class CFG:
    emb_dim = 200

args = CFG

# %%
# Train or load w2v model

TRAIN_W2V = True
try:
    model = Word2Vec.load('/content/drive/MyDrive/Colab Notebooks/구내식당 식수인원/food_embedding.model')
    print("Model loaded")
except:
    if TRAIN_W2V:
        print("Training w2v")
        model = Word2Vec(sentences=food_combinations, size=args.emb_dim, window=7, min_count=0, workers=4, sg=0)
        model.save('/content/drive/MyDrive/Colab Notebooks/구내식당 식수인원/food_embedding.model')
    else:
        print("Model loading failed. Do not train.")

# %%
# w2v demo
model.wv.most_similar('된장찌개')

# %%
def process_date(df):
    df['일자'] = pd.to_datetime(df['일자'], format="%Y-%m-%d")
    df['year'] = df['일자'].dt.year
    df['month'] = df['일자'].dt.month
    df['day'] = df['일자'].dt.day
    df = df.drop('일자', axis=1)
    return df

def get_food_embedding(x):
    x_ = []
    x = x.split(' ')
    for i in x:
        if '(' in i and ':' in i and ')' in i:
            continue
        if '/' in i:
            x_.extend(i.split('/'))
        else:
            x_.append(i)
    x_ = list(set(x_))
    x_.remove('')
    vec_ = np.zeros(args.emb_dim)
    for i in x_:
        vec = model.wv.get_vector(i)
        vec_ += vec
    vec_ /= len(x_)
    return vec_

# %%
# General preprocessing
df_train = process_date(train)
day_encoder = LabelEncoder()
df_train['요일'] = day_encoder.fit_transform(df_train['요일'])

# %%
# Get embedding
df_train['조식메뉴_embedding'] = df_train['조식메뉴'].apply(lambda x: get_food_embedding(x))
df_train['중식메뉴_embedding'] = df_train['중식메뉴'].apply(lambda x: get_food_embedding(x))
df_train['석식메뉴_embedding'] = df_train['석식메뉴'].apply(lambda x: get_food_embedding(x))

# %%
y_lunch = df_train['중식계']
y_dinner = df_train['석식계']
df_train.drop(['조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계'], axis=1, inplace=True)

# %%
X_common = df_train.iloc[:, :9]

# %%
emb_arr_lunch = np.array(df_train.iloc[:, 10].to_numpy().tolist()) # Ver 2
emb_arr_dinner = np.array(df_train.iloc[:, 11].to_numpy().tolist()) # Ver 2

X_train_lunch = np.concatenate((X_common.to_numpy(), emb_arr_lunch), axis=1)
X_train_dinner = np.concatenate((X_common.to_numpy(), emb_arr_dinner), axis=1)

# %%
X_train_lunch, X_test_lunch, y_train_lunch, y_test_lunch = train_test_split(X_train_lunch, y_lunch, test_size=0.1, random_state=42)
X_train_dinner, X_test_dinner, y_train_dinner, y_test_dinner = train_test_split(X_train_dinner, y_dinner, test_size=0.1, random_state=42)
